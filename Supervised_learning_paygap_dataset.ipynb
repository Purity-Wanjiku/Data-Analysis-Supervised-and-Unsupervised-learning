# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
pay_gap_df=pd.read_csv('pay_gap_Europe.csv')

# %%
pay_gap_df.head(10)
# Out:
#    Country  Clean-Country  Year    GDP  Clean-GDP  Urban_population  \
# 0  Austria              1  2010  35390          2             57.40
# 1  Austria              1  2011  36300          2             57.12
# 2  Austria              1  2012  36390          2             57.15
# 3  Austria              1  2013  36180          2             57.34
# 4  Austria              1  2014  36130          2             57.53
# 5  Austria              1  2015  36140          2             57.72
# 6  Austria              1  2016  36390          2             57.91
# 7  Austria              1  2017  36980          2             58.09
# 8  Austria              1  2018  37690          2             58.30
# 9  Austria              1  2019  38090          2             58.52
#
#    Clean-Urban_pop  Industry  Industry-fillna  Clean-Industry  ...  \
# 0                1      24.0             24.0               3  ...
# 1                1      23.5             23.5               3  ...
# 2                1      22.9             22.9               3  ...
# 3                1      22.3             22.3               3  ...
# 4                1      22.2             22.2               3  ...
# 5                1      21.8             21.8               3  ...
# 6                1      20.8             20.8               3  ...
# 7                1      20.7             20.7               3  ...
# 8                1      20.4             20.4               3  ...
# 9                1      19.9             19.9               3  ...
#
#    Accommodation  Information  Financial  Professional_scientific  \
# 0            9.9         21.2       30.3                     34.0
# 1            NaN          NaN        NaN                      NaN
# 2            NaN          NaN        NaN                      NaN
# 3            NaN          NaN        NaN                      NaN
# 4            7.4         22.9       30.4                     31.5
# 5            6.4         22.4       30.3                     31.3
# 6            5.9         20.9       27.1                     30.4
# 7            5.7         20.6       28.4                     29.4
# 8            5.4         20.7       28.2                     28.3
# 9            4.9         20.3       28.0                     27.5
#
#    Administrative  Public_administration  Education  Human_health  Arts  Other
# 0            22.5                    NaN       27.8          12.0  34.0   32.0
# 1             NaN                    NaN        NaN           NaN   NaN    NaN
# 2             NaN                    NaN        NaN           NaN   NaN    NaN
# 3             NaN                    NaN        NaN           NaN   NaN    NaN
# 4            19.5                    NaN       24.3          12.8  26.6   28.8
# 5            20.0                    NaN       24.2          12.9  26.2   28.3
# 6            17.8                    NaN       24.3          14.5  20.8   27.8
# 7            17.4                    NaN       23.7          15.0  19.1   26.9
# 8            17.1                    NaN       23.6          15.3  18.3   26.4
# 9            16.8                    NaN       23.4          14.9  17.4   25.7
#
# [10 rows x 38 columns]

# %%
columns_to_drop=['Country','Year','GDP','Urban_population','Industry','Industry-fillna','Industry-Mean','Business','Business-mean','Business-fillna','Mining','Mining-mean','Mining-fillna','Manufacturing-mean','Manufacturing-fillna','Manufacturing','Electricity_supply','Water_supply','Construction','Retail trade','Transportation','Accommodation','Information','Financial','Professional_scientific','Administrative','Public_administration','Education','Human_health','Arts','Other']

# %%
pay_gap_df=pay_gap_df.drop(columns_to_drop, axis=1)

# %%
pay_gap_df.head(6)
# Out:
#    Clean-Country  Clean-GDP  Clean-Urban_pop  Clean-Industry  Clean-Business  \
# 0              1          2                1               3               3
# 1              1          2                1               3               3
# 2              1          2                1               3               3
# 3              1          2                1               3               3
# 4              1          2                1               3               3
# 5              1          2                1               3               3
#
#    Clean-Mining  Clean-Manufacturing
# 0             3                    3
# 1             2                    2
# 2             2                    2
# 3             2                    2
# 4             3                    3
# 5             2                    3

# %%
pay_gap_df.dtypes
# Out:
# Clean-Country          int64
# Clean-GDP              int64
# Clean-Urban_pop        int64
# Clean-Industry         int64
# Clean-Business         int64
# Clean-Mining           int64
# Clean-Manufacturing    int64
# dtype: object

# %%
pay_gap_df.fillna(0)
# Out:
#      Clean-Country  Clean-GDP  Clean-Urban_pop  Clean-Industry  \
# 0                1          2                1               3
# 1                1          2                1               3
# 2                1          2                1               3
# 3                1          2                1               3
# 4                1          2                1               3
# ..             ...        ...              ...             ...
# 319             27          3                2               2
# 320             27          3                2               3
# 321             27          3                2               3
# 322             27          3                2               3
# 323             27          3                2               2
#
#      Clean-Business  Clean-Mining  Clean-Manufacturing
# 0                 3             3                    3
# 1                 3             2                    2
# 2                 3             2                    2
# 3                 3             2                    2
# 4                 3             3                    3
# ..              ...           ...                  ...
# 319               2             2                    2
# 320               3             2                    2
# 321               2             2                    2
# 322               2             2                    2
# 323               2             2                    2
#
# [324 rows x 7 columns]

# %%
pay_gap_df['Clean-Country'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sex_index=[1,2]

# %%
#create a correlation matrix
corr_matrix=pay_gap_df.corr()

# %%
sns.heatmap(corr_matrix, cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %%
Y=pay_gap_df['Clean-Country']

# %%
Y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 319    27
# 320    27
# 321    27
# 322    27
# 323    27
# Name: Clean-Country, Length: 324, dtype: int64

# %%
X=pay_gap_df.drop('Clean-Country',axis=1)

# %%
X
# Out:
#      Clean-GDP  Clean-Urban_pop  Clean-Industry  Clean-Business  Clean-Mining  \
# 0            2                1               3               3             3
# 1            2                1               3               3             2
# 2            2                1               3               3             2
# 3            2                1               3               3             2
# 4            2                1               3               3             3
# ..         ...              ...             ...             ...           ...
# 319          3                2               2               2             2
# 320          3                2               3               3             2
# 321          3                2               3               2             2
# 322          3                2               3               2             2
# 323          3                2               2               2             2
#
#      Clean-Manufacturing
# 0                      3
# 1                      2
# 2                      2
# 3                      2
# 4                      3
# ..                   ...
# 319                    2
# 320                    2
# 321                    2
# 322                    2
# 323                    2
#
# [324 rows x 6 columns]

# %%
from sklearn. model_selection import train_test_split
from sklearn. linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.4,random_state=101)

# %%
log_model=LogisticRegression()

# %%
X_train
# Out:
#      Clean-GDP  Clean-Urban_pop  Clean-Industry  Clean-Business  Clean-Mining  \
# 123          2                2               3               3             2
# 265          1                1               3               2             1
# 305          2                3               2               1             2
# 323          3                2               2               2             2
# 320          3                2               3               3             2
# ..         ...              ...             ...             ...           ...
# 40           1                1               1               1             2
# 75           2                3               2               2             2
# 87           1                2               3               3             3
# 63           1                2               3               2             3
# 11           2                1               3               3             2
#
#      Clean-Manufacturing
# 123                    3
# 265                    3
# 305                    1
# 323                    2
# 320                    2
# ..                   ...
# 40                     2
# 75                     2
# 87                     3
# 63                     3
# 11                     2
#
# [194 rows x 6 columns]

# %%
log_model.fit(X_train, y_train)
# Out:
# /home/user/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
LogisticRegression()
# Out:
# LogisticRegression()

# %%
predict=log_model.predict(X_test)

# %%
print(classification_report(y_test,predict))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         4
#            2       1.00      0.71      0.83         7
#            3       0.00      0.00      0.00         5
#            4       1.00      0.75      0.86         4
#            5       0.00      0.00      0.00         4
#            6       1.00      0.75      0.86         4
#            7       0.43      0.50      0.46         6
#            8       0.86      1.00      0.92         6
#            9       0.25      1.00      0.40         2
#           10       1.00      0.20      0.33         5
#           11       1.00      1.00      1.00         3
#           12       0.21      1.00      0.35         4
#           13       1.00      1.00      1.00         5
#           14       1.00      0.57      0.73         7
#           15       0.00      0.00      0.00         8
#           16       1.00      1.00      1.00         6
#           17       1.00      1.00      1.00         4
#           18       1.00      0.67      0.80         6
#           19       1.00      0.67      0.80         6
#           20       0.83      1.00      0.91         5
#           21       1.00      0.75      0.86         4
#           22       1.00      1.00      1.00         5
#           23       1.00      0.75      0.86         4
#           24       0.75      1.00      0.86         3
#           25       0.62      1.00      0.77         5
#           26       0.83      0.83      0.83         6
#           27       0.50      1.00      0.67         2
#
#     accuracy                           0.71       130
#    macro avg       0.75      0.75      0.71       130
# weighted avg       0.76      0.71      0.70       130
# /home/user/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/user/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/user/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
